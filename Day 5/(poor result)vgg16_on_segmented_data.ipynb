# %%
import tensorflow as tf
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.applications import VGG16, ResNet50
from tensorflow.keras.layers import Dense, Flatten, Dropout, GlobalAveragePooling2D
from tensorflow.keras.models import Model
from tensorflow.keras.optimizers import Adam

# %%
train_dir = r"F:\work\python\archive\segmented_dataset\train"
test_dir = r"F:\work\python\archive\segmented_dataset\test"

# %%
IMG_SIZE = 128
BATCH_SIZE = 32

train_datagen = ImageDataGenerator(rescale=1./255)

test_datagen = ImageDataGenerator(rescale=1./255)

train_generator = train_datagen.flow_from_directory(
    train_dir,
    target_size=(IMG_SIZE, IMG_SIZE),
    batch_size=BATCH_SIZE,
    class_mode='categorical'
)

test_generator = test_datagen.flow_from_directory(
    test_dir,
    target_size=(IMG_SIZE, IMG_SIZE),
    batch_size=BATCH_SIZE,
    class_mode='categorical',
    shuffle=False
)
# Out:
# Found 5000 images belonging to 4 classes.
# Found 1000 images belonging to 4 classes.

# %%
base_model = VGG16(weights='imagenet', include_top=False, input_shape=(128,128,3))

for layer in base_model.layers:
    layer.trainable = False

x = Flatten()(base_model.output)
x = Dense(256, activation='relu')(x)
x = Dropout(0.5)(x)
output = Dense(4, activation='softmax')(x)

model_vgg_seg = Model(inputs=base_model.input, outputs=output)

model_vgg_seg.compile(
    optimizer=Adam(learning_rate=0.0001),
    loss='categorical_crossentropy',
    metrics=['accuracy']
)

# %%
history_vgg_seg = model_vgg_seg.fit(
    train_generator,
    epochs=10,
    validation_data=test_generator
)
# Out:
# Epoch 1/10
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 202s 1s/step - accuracy: 0.4942 - loss: 1.1594 - val_accuracy: 0.6360 - val_loss: 0.9616
# Epoch 2/10
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 113s 721ms/step - accuracy: 0.6176 - loss: 0.9538 - val_accuracy: 0.7040 - val_loss: 0.8319
# Epoch 3/10
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 113s 720ms/step - accuracy: 0.6538 - loss: 0.8784 - val_accuracy: 0.7320 - val_loss: 0.7513
# Epoch 4/10
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 113s 721ms/step - accuracy: 0.6696 - loss: 0.8339 - val_accuracy: 0.7080 - val_loss: 0.7766
# Epoch 5/10
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 113s 719ms/step - accuracy: 0.6934 - loss: 0.7861 - val_accuracy: 0.7280 - val_loss: 0.7253
# Epoch 6/10
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 158s 1s/step - accuracy: 0.7012 - loss: 0.7612 - val_accuracy: 0.7240 - val_loss: 0.7220
# Epoch 7/10
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 123s 782ms/step - accuracy: 0.7162 - loss: 0.7398 - val_accuracy: 0.6860 - val_loss: 0.7661
# Epoch 8/10
# ...

# %%
base_model = ResNet50(weights='imagenet', include_top=False, input_shape=(128,128,3))

for layer in base_model.layers:
    layer.trainable = False

x = GlobalAveragePooling2D()(base_model.output)
x = Dense(256, activation='relu')(x)
x = Dropout(0.5)(x)
output = Dense(4, activation='softmax')(x)

model_resnet_seg = Model(inputs=base_model.input, outputs=output)

model_resnet_seg.compile(
    optimizer=Adam(learning_rate=0.0001),
    loss='categorical_crossentropy',
    metrics=['accuracy']
)

# %%
history_resnet_seg = model_resnet_seg.fit(
    train_generator,
    epochs=10,
    validation_data=test_generator
)
# Out:
# Epoch 1/10
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 73s 466ms/step - accuracy: 0.2580 - loss: 1.5154 - val_accuracy: 0.3580 - val_loss: 1.3442
# Epoch 2/10
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 67s 429ms/step - accuracy: 0.2660 - loss: 1.4561 - val_accuracy: 0.3970 - val_loss: 1.3401
# Epoch 3/10
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 75s 476ms/step - accuracy: 0.2810 - loss: 1.3997 - val_accuracy: 0.3880 - val_loss: 1.3377
# Epoch 4/10
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 77s 492ms/step - accuracy: 0.2942 - loss: 1.3827 - val_accuracy: 0.3830 - val_loss: 1.3276
# Epoch 5/10
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 67s 426ms/step - accuracy: 0.3072 - loss: 1.3657 - val_accuracy: 0.3900 - val_loss: 1.3143
# Epoch 6/10
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 73s 465ms/step - accuracy: 0.3198 - loss: 1.3586 - val_accuracy: 0.4810 - val_loss: 1.3058
# Epoch 7/10
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 119s 759ms/step - accuracy: 0.3434 - loss: 1.3483 - val_accuracy: 0.3170 - val_loss: 1.3002
# Epoch 8/10
# ...

# %%
loss, accuracy = model_resnet_seg.evaluate(test_generator)
print("Test Accuracy:", accuracy)

# %%
import numpy as np
from sklearn.metrics import classification_report, confusion_matrix

predictions = model_resnet_seg.predict(test_generator)
y_pred = np.argmax(predictions, axis=1)
y_true = test_generator.classes

print(confusion_matrix(y_true, y_pred))
print(classification_report(y_true, y_pred))
